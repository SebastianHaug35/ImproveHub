# %%
import openai
from openai import Completion

# Set your OpenAI API key
openai.api_key = "OPENAI_API_KEY_PLACEHOLDER"

# Create a Completion object and specify the prompt and model
completion = Completion.create(
    prompt="What is the meaning of life?",
    model="text-davinci-003"
)

# Get the completion from the response
completion = completion["choices"][0]["text"]

# Print the completion
print(completion)

# %%
import openai

# Set up the API key
openai.api_key = 'OPENAI_API_KEY_PLACEHOLDER'

def ask_chatgpt(question):
    try:
        # Make the API request
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "You are a helpful assistant."},
                {"role": "user", "content": question},
            ]
        )
        # Extract and return the answer from the response
        answer = response['choices'][0]['message']['content']
        return answer

    except openai.error.OpenAIError as e:
        # Handle any errors that occur
        return f"Error: {e}"

if __name__ == "__main__":
    question = "Who won the world series in 2020?"
    answer = ask_chatgpt(question)
    print(answer)

# %%
create title

find good videos/ books/ sources/ experts

create article with pictures

embed resources

# %%
Prompt: 
Write a blog article about the x
v = find good videos and other resources about x and give me the links
find me good
