# %% [markdown]
# # Kerngeschäft
#
# Kunden überzeugen
# - Content planen
# - Netwerken
# - Loyalität aufbauen
#
# Vision
# - werte leben
# -
#
# Team
# - Coachen
# - neue werben
# - Tutorials: Design-Thinking Tools
# - Netwerken
# - Loyalität aufbauen
# - Decide on Who is in my Team? Who do i allow to be on my team?
#
# Strategie
# - Research: Know your battlefield! Know your opponents! Know History! Stay alert and agil!
# - Kommunikationsstrategie vorantreiben
# - Contentstrategie
# - Execution-Strategie vorantreiben
# > Planen & Aufgaben vergeben
# > Weiterbildungen organisieren

# %% [markdown]
# KPIs:
# - How many delegated tasks are getting done per week

# %% [markdown]
# <http://localhost:8888/notebooks/ImproveHUB%2FKW47-50.ipynb
# 	neue werben
# 	Tutorials
# 	Netwerken
# 	Loyalität aufbauen
# 	Decide on Who is in my Team? Who do i allow to be on my team?

# %% [markdown]
# <body>
#     <div style="width: 30%; display: inline-block;">
#         <h3>Execution</h3>
#         Verantwortlich: Basti
#         <img src="image_resources/chess-king.png">
#     </div>
#     <div style="width: 30%; display: inline-block;">
#         <h3>Marketing&Vertrieb</h3>
#         Verantwortlich: Philipp und Lisa
#         Provisionsplan für Anwerben von Youtubern
#         <img src="image_resources/chess-queen.png">
#     </div>
#     <div style="width: 30%; display: inline-block;">
#         <h3>Team</h3>
#         <div>Philipp</div>
#         <div>David</div>
#         <div>Lisa</div>
#         <h3>Mentoren</h3>
#         <div>Julia Zupf</div>
#         <div>Thomas Möst</div>
#         <div>Sebastian Dünnebeil</div>
#         <div>Max Strasser</div>
#         Team:
#         Ersatzbank: Niko, Ludwig, Bryan
#         <img src="image_resources/chess-bishop.png">
#     </div>
# </body>
#
# <body>
#     <div style="width: 30%; display: inline-block;">
#         <h3>Produkt-Ideen</h3>
#         <div>Youtube-Bots</div>
#         <div>Community Spcces (Philipp)</div>
#         <div>Zitate (Lisa)</div>
#         <div>gemeinsame Herausforderungen erstellen (Lisa)</div>
#         <div>Daten von Fitnessuhren Mentoren zur Verfügung stellen (Lisa)</div>
#         <h3>Marketing-Ideen</h3>
#         <div>Kostenlos ChatGPT4-API für zweianfragen/tag um nutzer zu gewinnen</div>
#         <img src="image_resources/chess-pawn.png">
#     </div>
#     <div style="width: 30%; display: inline-block;">
#         <h3>Produkt</h3>
#         Verantwortlich: Basti
#         <img src="image_resources/chess-knight.png">
#     </div>
#     <div style="width: 30%; display: inline-block;">
#         <h3>Finances</h3>
#         Verantwortlich: David
#         <img src="image_resources/chess-pawn.png">
#     </div>
# </body>

# %% [markdown]
# ### Pitch für Nutzer
#
# 1.
# what is your biggest regret?
# for me first it was the decision to start an apprenticeship as an electrician.
# for 4 years i mostly worked on the construction side.
# - hard, tedious work
# - without much pay
# - and no real career oportunities
#
# 2.
# - Good advice didnt came from the people around me
#
# But from the audiobooks I listen to each day. The autors of those books gave me the advice i needed
# That helped me to shorten my apprenticeship, get an high school diploma and gave me the oportunity to study computer sciences.
# 3.
# Solution:
# Everyone of us needs the right advice at the right time to achieve our goals.
# Let us help you get this advice.
# Our Team created a way to get the knowledge of successfull people without needing to read long books or listen to podcasts.
# Our product takes the videos of your idols and turns them into a chatbot which can give you advice specific to your situation
# Its like chatgpt that knows you and gives you the advice from idols you trust.
# 4.
# Who is your biggest idol? who do you desire to talk to once in your lifetime?
# - let the wisdom of your greatest idols work for you
# turn the people you admire into your personal mentor
# A mentor which is always there when you need it. 24/7.
# Use the app to gain outside advice from someone who wont judge your ideas but will support them
# 5.
# Call to Action:
# - get the mentor you deserve
# - scan the link now and be one of the first to get access to a mentor
#
#
# ### Pitch an Youtuber...
# - Benefits für Youtuber: USP durch AI-Bot, Affiliate-Einnahmen, Aufmerksamkeit, zusätzliches günstiges Angebot in ihrem Sortiment um in Ihr Ökosystem zu komme

# %% [markdown]
# ### Kommunikationsstrategie:
# 1. Ziele:
# - Reichweite aufbauen und Leute auf Umfrage lenken, um Feedback zu bekommen und Interesse abschätzenn zu können
# - Content als Referenz für Gespräche mit YouTubern/ Coaches
# - täglich 2 Posts auf Insta
# - 1-4 Content auf Tiktok
# - 1-5 tweets per day (X-Twitter)
# - have consitent content for next 5 years
# - get outreach from bigger channels where you use their content from
# - create Sample-AI Assistant which is a clone of the user itself which interacts with the assistants
#
# 2. Zielgruppe:
# - junge leute von 15-30 Jahren
# - zielstrebig
# - schätzen persönliche Weiterentwicklung sehr hoch und können sich Produkt für 20-30€/Monat leisten
# 3. Message:
# - wir sind ein junges StartUp und wollen mit Dir unser Produkt entwickeln. Du kannst entscheiden, was das Produkt machen können soll!
# - wir bauen für dich den perfekten Mentor für Dein Leben
# - generell content produzieren, welcher nicht direkt mit unserer produktumsetzung zu tun hat aber einfach deie leute unterstützt
# 4. Kanäle:
# - Instagram, TikTok, LinkedIn, X
# 50% des Contents sollte auf privaten Kanälen gepublisht werden, welche wir retweeten und dann verlinken
# 5. Budget:
# - ?

# %% [markdown]
# ### Marketing-/Contentstrategie:
#
# Nächster Karriereschritt:
# -User:  Lebenslauf eingeben
# Interaktion: - Ziel eingeben
# ChatBot:
# - Nächste Schritte vorscgenhla
#
# Stimulanz - Answer in Style of Hamza:
# - how can i become adonis?
# - my son...
# - zyzz motivation als werbung nehmen. generell die Musik einbauen
#
# Workout-Bot:
# - how can i train my bizeps
# - vorschlag an tool liste als große Buttons: Trainingsplan erstellen
# - Artikel lesen/ Trainingsplan nutzen
#
# Motivations-Content erstellen:
# - how can i train my bizeps
# - vorschlag an tool liste als große Buttons: Newsartikel erstellen
# - Artikel lesen
#
# Useful ai-generierte Trainingstipps publishen: (erst als Tweet um Interesse zu sehen, dann Tiktok, dann Insta...)
# - zitat einer perönlichkeit + link zu generierten Blog zu dem Thema
#
# Useful ai-generierte Strategie-Tipps publishen: (erst als Tweet um Interesse zu sehen, dann Tiktok, dann Insta...)
# - zitat einer perönlichkeit + link zu generierten Blog zu dem Thema
#
# Praxisorientierte Strategiebeispiele:
# - your boss is afraid of you? you will desperatly want to get ahead
# - chatbot strategic answer
# - zyss-logo am ende
#
# Brain-Tutor:
# - Fakten eingeben
# - assoziationen finden
# - geschichte erstellen
# - leichter dann dran erinn
#
# Create Own Character:
# - Select Characters
# - Select Tools. Create Plan. To Image...
# - Be able to make your Character public and capitalize on it
#
# Social-Media-Manager-Gary-Vee:
#
#
# POV:
# - needs meditation that changes and isnt the same every time
#
# Meditationsguide-Sam-Harris:
# - button that you want to start a session
# - sam-harris asks questions what to do
# - guided-meditation...!gen

# %% [markdown]
# # Competitor-Research
# https://www.wemadeastory.com/
#
# <img src="image_resources/shareStory.png">
#
#
#
# https://twitter.com/quivr_brain
#
# https://torq.io/use-cases/#invalid-login
#
# https://twitter.com/personabotsi -> Gott
#
# Youtube-Bot Aspirations: https://www.theverge.com/2023/11/7/23950327/youtube-artificial-intelligence-chatbot-video-summaries-ask-comments-topics-categorization
#
#
# socratic chatbot: https://beta.character.ai/chat?char=6HhWfeDjetnxESEcThlBQtEUo0O8YHcXyHqCgN7b2hY&default_text_code=2
#
# https://mana.ai/
#
# pocketcoach ai

# %% [markdown]
# # MVP
#
#
# http://localhost:8888/notebooks/ImproveHUB/Research/MinimalViableProduct.ipynb
#
# Mvp
# - Buttons für Zehn Jahresplan, Artikel oder Habits
# - <s>Chatverlauf umdesignen mit Arbeitsimplementierung
# - <s>Feedback Kanale einbauen
# - <s>Icon chatverlauf andern bei auwahl von chatbot
# - Banner von Philipp umdesignen lassen
# - Alle mit den ich zusammenarbeiten wikl schonmal warm netzwerken und aufgaben ver
# teilen
# - Warte-Animation bei Request angeben. Drehende Icons
#
# Youtuber:
# - Brain-Mentor
#
# Components:
# interface: select mentor + select vectorstores
# Vectorstore-class

# %% [markdown]
# ### USP
# - specific tools
# - capitalize on own character
# - visualize output
# -

# %% [markdown]
# ### Exit-Strategien
# - Zusammenarbeit/ Übernahme von Youtuber oder SocialMediaInfluencer

# %% [markdown]
# # Competitor Analyze/ Ocean Strategy
# ans.

# %% [markdown]
# Whatsapp-API
# https://www.twilio.com/en-us/messaging/channels/whatsapp?utm_source=google&utm_medium=cpc&utm_term=whatsapp%20api&utm_campaign=G_S_EMEA_NB_WhatsApp_T1_EN_NV&cq_plac=&cq_net=g&cq_pos=&cq_med=&cq_plt=gp&gad_source=1&gclid=CjwKCAiA1fqrBhA1EiwAMU5m_6-foxpF7LryksTe2sVPCFW6Wo6DJ61okfteN7R7vuKRVEzgN68cXhoC2zMQAvD_BwE
