# %% [markdown]
# <img src="Tesla-Line.jpg" width="" align="" />

# %% [markdown]
# Einwände von Entwicklern: Habe keine Zeit -> direkte Aufgaben... so viel du kannst -> siehst direkte Erfolg von kleinen Tasks

# %% [markdown]
# * Problem
# > do you know when you learned about x...
# >> how this completely changed you life...
# >> but nobody told you about it before. To the right time.
# >>Often we are to afraid to tell people directly in their face, what they are lacking.
# >>> imagine if you had somebody told x you that early in life. Imagine your kids having the opportunity to learn about x before they do the mistakes
# >>>> our day to day landscape comes increasingly more distractive. People are more social-media governed bots than self-determined people. Do you want to make a difference. Improve your life and that of your family -> to saveguard from social-media influence and to see what is possible with ai-supported selfimprovement
# * Solution
# Selfimprovement through AI
# * USP
# > AI-Assistant
# * Unfair Advantage
# > Knowledge AI + large Team of Programmers
# * Timing
# > Chat-Bot Revolution
# * Market
# * Business Model
# * Milestones
# > Selfimprovement Wiki. Knowledge-generated & governed by AI-Bots
# >> AI-Assistant for Wiki
# >>> Selfimprovement Hub without distractions
# >>> Products: AI-Assistant for Health and Workoutplan / App | Meditation AI Assistant / App | Kommunikation Assistant / App | Information App / which concentrates on providing Background material
# >>>> Selfimprovement-Hub. Give Collaborators like Hamza an App
#
# * Team
# @Sandra
# @Jannik
# @Johannes
# @Niko (FK07-App-Entwicklung)
# @David (MMS)
# @Marius (APE)
# @Georg (Arbeit)
# @Phillipp (MMS)
# @Dominik (JuLis)
# * Call to Action

# %% [markdown]
# ## Market

# %% [markdown]
# ## Prototyp

# %% [markdown]
# <img src="messaging-apps.jpg" width="" align="" />

# %% [markdown]
# ## Competitor Research

# %% [markdown]
# not found yet: https://sl.bing.net/jg6IPTKT4xw

# %% [markdown]
# ## Business Model

# %% [markdown]
# B2B:
# - sell to Coaches
# - provide Maintaince-Contracts
#
#
#
# B2C-Abo-Model:
# - sell over Coaches
# - Affiliate-Marketing: Use Influencer usw

# %% [markdown]
# ## Milestones

# %% [markdown]
# Proof of Concept
# > 1. Prototyp erstellen
# > 2. Testpersonen: @David, @Ludwig

# %% [markdown]
# Proof of Interest
# > Vertrieb: @David mit reinnehmen

# %% [markdown]
# Proof of Investments

# %% [markdown]
# ## Team

# %% [markdown]
# @Sandra
# @Jannik
# @Johannes
# @Niko (FK07-App-Entwicklung)
# @David (MMS)
# @Marius (APE)
# @Georg (Arbeit)
# @Phillipp (MMS)
# @Dominik
# @Nico (APE-Alumni)(JuLis)

# %% [markdown]
# Positionen
# > Marketing & Vertrieb
# > Kundenfeedback, Tests
# > Software-Entwicklung
# > Content-Verantwortliche.  + Content-Creation
# > Public Relations: Kümmern um Kollaborationen + Kommunikationsstrategie
#     PR-Guide nutzen
#     Start with why
